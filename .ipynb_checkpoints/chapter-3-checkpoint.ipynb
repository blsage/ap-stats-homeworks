# %% [markdown]
# # Chapter 3 Homework

# %%
require(mosaic)
trellis.par.set(theme=col.mosaic())  # get a better color scheme for lattice
options(digits=3)

# %% [markdown]
# ## 2.111

# %% [markdown]
# ### a.
# 3,388,000

# %% [markdown]
# ### b.

# %%
data <- data.frame(full.time=c(3388, 5238, 1703, 762), part.time=c(389, 1164, 1699, 2045))
joint.distribution <- data / (sum(data$full.time) + sum(data$part.time))
joint.distribution
# Out:
#   full.time  part.time
# 1 0.20673664 0.02373688
# 2 0.31962412 0.07102758
# 3 0.10391750 0.10367342
# 4 0.04649744 0.12478643

# %% [markdown]
# ### c.

# %%
age.marginal.distribution <- (joint.distribution$full.time + joint.distribution$part.time) * 100
age.marginal.distribution
pie(age.marginal.distribution, labels=c("15-19", "20-24", "25-34", "35 and over"), main="Age Marginal Distribution")
# Out:
# [1] 23.04735 39.06517 20.75909 17.12839
# Plot with title “Age Marginal Distribution”

# %% [markdown]
# ### d.

# %%
status.marginal.distribution <- c(sum(joint.distribution$full.time), sum(joint.distribution$part.time))
status.marginal.distribution
pie(status.marginal.distribution, labels=c("Full-time", "Part-time"), main="Status Marginal Distribution")
# Out:
# [1] 0.677 0.323
# Plot with title “Status Marginal Distribution”

# %% [markdown]
# ## 2.112

# %%
conditional.distribution <- data
conditional.distribution[1,] <- 100 * conditional.distribution[1,] / sum(conditional.distribution[1,])
conditional.distribution[2,] <- 100 * conditional.distribution[2,] / sum(conditional.distribution[2,])
conditional.distribution[3,] <- 100 * conditional.distribution[3,] / sum(conditional.distribution[3,])
conditional.distribution[4,] <- 100 * conditional.distribution[4,] / sum(conditional.distribution[4,])
conditional.distribution
# Out:
#   full.time part.time
# 1 89.70082  10.29918
# 2 81.81818  18.18182
# 3 50.05879  49.94121
# 4 27.14642  72.85358

# %%
for (n in 1:nrow(conditional.distribution)) {
    pie(as.numeric(conditional.distribution[n,]), labels=c("Full-time", "Part-time"))
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# All of the distributions seemed to have different proportions. There is a general trend that a higher age coincides with a greater proportion of part-time students.

# %% [markdown]
# ## 2.113

# %%
conditional.distribution <- data
conditional.distribution$full.time <- 100 * conditional.distribution$full.time / sum(conditional.distribution$full.time)
conditional.distribution$part.time <- 100 * conditional.distribution$part.time / sum(conditional.distribution$part.time)
conditional.distribution
# Out:
#   full.time part.time
# 1 30.547291  7.343779
# 2 47.227482 21.974703
# 3 15.354792 32.074759
# 4  6.870435 38.606759

# %%
ft <- pie(conditional.distribution$full.time, labels=c("15-19", "20-24", "25-34", "35 and over"), main="Status Conditional Distribution")
pt <- pie(conditional.distribution$part.time, labels=c("15-19", "20-24", "25-34", "35 and over"), main="Status Conditional Distribution")
paste(ft, pt)
# Out:
# Plot with title “Status Conditional Distribution”
# character(0)
# Plot with title “Status Conditional Distribution”

# %% [markdown]
# The distributions have approximately the same proportions. However, in each group conditional distribution, the groups with each proportion differed.

# %% [markdown]
# ## 2.117

# %% [markdown]
# ${a, b, c, d} = {150, 50, 50, 150}$ or ${a, b, c, d} = {100, 100, 100, 100}$

# %% [markdown]
# ## 2.119

# %% [markdown]
# ### a.

# %%
survey <- read.csv("./data-tables/ex02_119.csv")
survey$Percentage <- 100 * survey$Count / 300
survey
# Out:
#   Group Size   Response Count Percentage
# 1 1     Small  Yes      175   58.3
# 2 2     Small  No       125   41.7
# 3 3     Medium Yes      145   48.3
# 4 4     Medium No       155   51.7
# 5 5     Large  Yes      120   40.0
# 6 6     Large  No       180   60.0

# %%
100 * (125 + 155 + 120) / 900
# Out:
# [1] 44.44444

# %% [markdown]
# ### b.

# %%
100 * 125 / 300
100 * 180 / 300
# Out:
# [1] 41.66667
# [1] 60

# %% [markdown]
# It seems as though a smaller business corresponds to a lower percentage of nonresponse. While the average small business had a nonresponse percent of about 41.7%, the average large business had a rate of 60%.

# %% [markdown]
# ### c.

# %%
barchart(Percentage ~ Size, data=survey[survey$Response=="No",])
# Out:
# plot without title

# %% [markdown]
# ### d.

# %%
total <- 175 + 145 + 120
paste("Small: ", 100 * 175 / total)
paste("Medium: ", 100 * 145 / total)
paste("Large: ", 100 * 120 / total)
# Out:
# [1] "Small:  39.7727272727273"
# [1] "Medium:  32.9545454545455"
# [1] "Large:  27.2727272727273"

# %% [markdown]
# ### e.

# %% [markdown]
# The marginal distributions of these data are so skewed that it is not at all unreasonable to think that there are strong lurking variables corrupting the data.

# %% [markdown]
# ## 2.123

# %% [markdown]
# Possible confounding variables:
# * Age (Married men are often older)
# * Emotional Intelligence (Married men are more likely to have strong social skills)

# %% [markdown]
# Man's merital status <- - -> Man's age <- - -> Man's wealth
#
# Man's merital status --?--> Man's wealth
#
# Man's age --?--> Man's wealth

# %% [markdown]
# ## 2.125

# %% [markdown]
# No, it does not. Fitness and confidence could both be a common response to another trait, or, the strong confidence could be what causes the fitness to increase.

# %% [markdown]
# ## 2.129

# %% [markdown]
# Miscarriages <- - -> Working in computer chip production
#
# Chemicals <- - -> Working in chip produciton <- - -> Standing
#
# Chemicals --?--> Miscarriages
#
# Standing --?--> Misscarriages

# %% [markdown]
# ## 2.131

# %% [markdown]
# Possible lurking variables:
# * Amount of sleep
# * Short attention spans
# * Discipline of parents

# %% [markdown]
# ## 3.1

# %% [markdown]
# To quite a small extent. I probably am friends with an abnormal percentage of people who also like "Final Fu," which skews my perspective about the actual percentage of people at the college who like the show.

# %% [markdown]
# ## 3.3

# %% [markdown]
# Jamie and his likely computer-programmer friends probably enjoy jolt cola more than the average person because they spend long nights staying awake coding misc. gizmos like robots.

# %% [markdown]
# ## 3.7

# %% [markdown]
# This is an observational study. The researchers are looking at people who have already been exposed to the micorwave radiation of cell phones. They are not trying to observe the responses to a certain type of treatment. The explanatory variable is the use of cell phones, and the response is brain cancer.

# %% [markdown]
# ## 3.8

# %% [markdown]
# ### a.

# %% [markdown]
# This is an observational study because the reasearchs are simply investigating people who have already undergone an experience. There was no intentional treatment.
#
# Explanatory variable: time spent watching TV as a child
#
# Response variable: aggressive behavior

# %% [markdown]
# ### b.

# %% [markdown]
# * Attention from parents
# * Time (and effort) spent on schoolwork
# * Time spent exercising
#
# Because of all the possible lurking and confounding variables, it is very difficult to definitively decide which one is causing the aggressive behavior. It is likely a combination of many factors.

# %% [markdown]
# ## 3.9

# %% [markdown]
# Yes, this is an experiment. The researchers are giving a specific treatment to each half of the population, then observing the results of that experiment.
#
# Explanatory variable: medium of education
#
# Response variable: retention of material

# %% [markdown]
# ## 3.17

# %% [markdown]
# ### a.

# %% [markdown]
# This is lacking randomization. The results are biased, because there might be a type of student who sits in the front of class who is different from the type of student who sits in the back of the class. In order to fix this, the labs should be given out to students randomly.

# %% [markdown]
# ### b.

# %% [markdown]
# The experiment needs a control group.

# %% [markdown]
# ### c.

# %% [markdown]
# The method needs to be more easily comparable. One way to accomplish this is by having students learn the same material at the same time with some learning with the traditional method and some learning using the new method.

# %% [markdown]
# ## 3.19

# %% [markdown]
# Double-blind fashion will be key to this experiment. For one, the student should not know whether they got the new or the traditional method. Also, the test evaluators should not know whether the student got the new or the old method.

# %% [markdown]
# ## 3.23

# %% [markdown]
# Experimental units: pine trees
#
# Factors: amount of light
#
# Treatments: Full light, light reduced to 5% with shade cloth
#
# Response variables: final dry weight

# %% [markdown]
# ### 3.27

# %% [markdown]
#                 - Group 1 ---> Treatment 1 (antidepressant alone)
#
#
#                 - Group 2 ---> Treatment 2 (placebo alone)
#
# - The Subjects-----------------------------------------------------------------------------------------------------------------------Compare headaches
#
#                 - Group 3 ---> Treatment 3 (antidepressant + stress management)
#
#
#                 - Group 4 ---> Treatment 4 (placebo + stress management)

# %%
names <- c("Anderson", "Chronopoulou", "Guha", "Leaf", "Mehta", "Paul", "Towers", "Xu",
          "Archberger", "Codrington", "Hatfield", "Li", "Mi", "Rau", "Tyner", "Bezawada",
          "Daggy", "Hua", "Lipka", "Nolan", "Saygin", "Vassilev", "Cetin", "Daye",
          "Kim", "Lu", "Olbricht", "Shu", "Wang", "Cheng", "Engelbrecht", "Kumar",
          "Martin", "Park", "Tang", "Watkins")
group.size <- length(names) / 4

group1 <- sample(names, group.size)
names <- names[!names %in% group1]
group2 <- sample(names, group.size)
names <- names[!names %in% group2]
group3 <- sample(names, group.size)
group4 <- names[!names %in% group3]

groups <- data.frame(group1=group1, group2=group2, group3=group3, group4=group4)
groups
# Out:
#   group1     group2       group3      group4
# 1 Cheng      Watkins      Cetin       Leaf
# 2 Codrington Chronopoulou Saygin      Paul
# 3 Hatfield   Li           Bezawada    Lipka
# 4 Daggy      Hua          Xu          Daye
# 5 Anderson   Wang         Rau         Kim
# 6 Tang       Lu           Towers      Olbricht
# 7 Nolan      Mi           Engelbrecht Shu
# 8 Guha       Park         Tyner       Kumar
# 9 Archberger Mehta        Vassilev    Martin

# %% [markdown]
# ## 3.39

# %% [markdown]
# ### a.

# %% [markdown]
# Randomized: In order to ensure that the treatment groups are similar (except in chance deviation), randomization uses chance to choose which subjects should be in each treatment group
#
# Double-blind: This means that the subjects do not know whether they have the drug or the placebo, and the researchers or testers do not know which subjects have the drug and which have the placebo.
#
# Placebo-controlled: A placebo control is very important because it helps establish how far the drug devaiates from random chance. In other words, it sets the baseline. The placebo is a version of the drug that is identical in form but has no effect on the body.

# %% [markdown]
# ### b.

# %% [markdown]
#         - Group 1 ---> Treatment 1 (Saint-John's-worth extract)
#
# Subjects---------------------------------------------------------------------------------------Compare rate of change in Hamilton Rating Scale for depression
#
#         - Group 2 ---> Treatment 2 (Placebo)

# %% [markdown]
# ## 3.53

# %% [markdown]
# ### a.

# %% [markdown]
# If you choose from a single chapter, that's not really random. Instead, you should choose random words from random pages.

# %% [markdown]
# ### b.

# %% [markdown]
# By handing out questionnaires, you are limiting your audience to the types of people who would take 7:30 am classes.

# %% [markdown]
# ### c.

# %% [markdown]
# The sample is not truly random, because each subject did not have an equal chance of being chosen. Names could be more likely to be picked due to ethnicity or gender.

# %% [markdown]
# ## 3.55

# %% [markdown]
# ### a.

# %% [markdown]
# Population: Americans 18 and older
# Sample size: 1001

# %% [markdown]
# ### b.

# %% [markdown]
# There might be some bias if you include only the people who provided an opinion, because they are more likely to support the person fince they know who they are. I believe that this is the stronger approach, though, because voting is not compulsory, so the people who are elected only need to win over the people who are going to vote.

# %% [markdown]
# ## 3.57

# %%
population <- 3 * 11
sample(population, 5)
# Out:
# [1] 23 33  3 16 22

# %% [markdown]
# In the book, these numbers correspond to:
#
# * Mayfair Village
# * Williamsburg
# * Beau Jardin
# * Fairington
# * Lahr House

# %% [markdown]
# ## 3.61

# %% [markdown]
# For this, I used two numbers in the table of random digits, and I included 1-44 and threw out the other numbers. I numbered the blocks starting at 1000 and incremented by 1 for each block. Here are the blocks I determined:
# * 39 - block 3020
# * 10 - block 2003
# * 07 - block 2000
# * 11 - block 2004
# * 20 - block 3001

# %% [markdown]
# ## 3.63

# %% [markdown]
# For group 1, I assigned the number 0-5 to the group 1 blocks. Using that, I determined my block to be:
#
# * 0 - block 1000
#
# I then chose 2 blocks in group 2, using the numbers 00-11. I determined my blocks to be:
#
# * 08 - block 2008
# * 11 - block 2011
#
# I then chose 3 blocks in group 3, using the numbers 00-25. I determined my blocks to be:
#
# * 16 - block 3016
# * 08 - block 3008
# * 22 - block 3022

# %% [markdown]
# ## 3.71

# %% [markdown]
# The period of July 1 to August 31 probably had fewer answers because it was summertime in the Northern Hemisphere, and many families were likely away. A high rate of no responses makes the chances greater that some type of lurking variable is causing a certain type of person to not answer the phone.

# %% [markdown]
# ## 3.73

# %% [markdown]
# ### a.

# %%
631 + 564 + 65
# Out:
# [1] 1260

# %% [markdown]
# ### b.

# %%
paste("yes ", 100 * 631 / 1260)
paste("no ", 100 * 564 / 1260)
paste("not sure ", 100 * 65 / 1260)
# Out:
# [1] "yes  50.0793650793651"
# [1] "no  44.7619047619048"
# [1] "not sure  5.15873015873016"

# %% [markdown]
# ### c.

# %% [markdown]
# Only the people who are visiting this site and feel compelled to respond (who are likely more passionate about the issue) appear in the data.

# %% [markdown]
# ## 3.83

# %% [markdown]
# ### a.

# %% [markdown]
# Population: U.S. four-year college students
#
# Sample: 17,096 students

# %% [markdown]
# ### b.

# %% [markdown]
# Population: restaurant workers
#
# Sample: 100 restaurant workers

# %% [markdown]
# ### c.

# %% [markdown]
# Population: longleaf pine trees
# Sample: 584 pine trees in a tract of forest

# %% [markdown]
# ## 3.85

# %% [markdown]
# ### a.

# %% [markdown]
# A smaller sample size leads to less information about a population. Often times, this means a higher variation and thus a wider margin of error.

# %% [markdown]
# ### b.

# %% [markdown]
# A very small sample size will just have too wide of a margin of error to make any meaningful predictions about the population.

# %% [markdown]
# ## 3.87

# %% [markdown]
# ### a.

# %% [markdown]
# No, the variability will not raise. This is because the same number of people are being sampled.

# %% [markdown]
# ### b.

# %% [markdown]
# Yes, there would be a lower variability in the states with higher populations.
